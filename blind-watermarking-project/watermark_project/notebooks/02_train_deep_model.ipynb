# %% [markdown]
# # Blind Watermarking Training Notebook
# Use this in Google Colab. Upload or mount your project folder from Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/blind-watermarking-project
# !pip install -r requirements.txt

# %%
# !python train.py
